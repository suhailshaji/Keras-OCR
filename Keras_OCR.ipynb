# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install keras-ocr

# %%
import keras_ocr
from matplotlib import pyplot as plt

# %%
pipeline = keras_ocr.pipeline.Pipeline()
# Out:
# Looking for /root/.keras-ocr/craft_mlt_25k.h5
# Downloading /root/.keras-ocr/craft_mlt_25k.h5
# Looking for /root/.keras-ocr/crnn_kurapan.h5
# Downloading /root/.keras-ocr/crnn_kurapan.h5

# %%
images = [keras_ocr.tools.read(img) for img in ['/content/drive/MyDrive/Keras-OCR/rect1.png',
                                               '/content/drive/MyDrive/Keras-OCR/rect2.png']

                                               ]

# %%
prediction=pipeline.recognize(images)
# Out:
# 1/1 [==============================] - 84s 84s/step
# 1/1 [==============================] - 2s 2s/step

# %%
prediction
# Out:
# [[('24m',
#    array([[237.1431  ,  21.277065],
#           [286.43118 ,  22.770641],
#           [285.86606 ,  41.420185],
#           [236.57797 ,  39.92661 ]], dtype=float32)),
#   ('15',
#    array([[602., 203.],
#           [628., 203.],
#           [628., 222.],
#           [602., 222.]], dtype=float32)),
#   ('m',
#    array([[632., 207.],
#           [650., 207.],
#           [650., 222.],
#           [632., 222.]], dtype=float32))],
#  [('32m',
#    array([[473.06784 ,  54.52591 ],
#           [602.0541  ,  55.959087],
#           [601.51514 , 104.46226 ],
#           [472.52893 , 103.029076]], dtype=float32)),
#   ('20',
#    array([[896.8633 , 305.42383],
#           [963.25977, 305.42383],
#           [963.25977, 354.45508],
#           [896.8633 , 354.45508]], dtype=float32)),
#   ('20',
#    array([[ 33.708984, 308.48828 ],
#           [100.10547 , 308.48828 ],
#           [100.10547 , 356.49805 ],
#           [ 33.708984, 356.49805 ]], dtype=float32)),
#   ('m',
#    array([[ 983.68945,  314.6172 ],
#           [1026.5918 ,  314.6172 ],
#           [1026.5918 ,  354.45508],
#           [ 983.68945,  354.45508]], dtype=float32)),
#   ('m',
#    array([[120.53516, 317.68164],
#           [164.45898, 317.68164],
#           [164.45898, 356.49805],
#           [120.53516, 356.49805]], dtype=float32)),
#   ('32m',
#    array([[472.94727, 571.00977],
#           [601.6543 , 571.00977],
#           [601.6543 , 621.0625 ],
#           [472.94727, 621.0625 ]], dtype=float32))]]

# %%
import numpy as np
print(np.shape(images))
# Out:
# (2,)
# /usr/local/lib/python3.10/dist-packages/numpy/core/fromnumeric.py:2009: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   result = asarray(a).shape

# %%
prediction_groups = pipeline.recognize(images)

# Plot
fig, axs = plt.subplots(nrows=len(images), figsize=(20, 20))
for ax, image, predictions in zip(axs, images, prediction_groups):
    keras_ocr.tools.drawAnnotations(image=image, predictions=predictions, ax=ax)
# Out:
# 1/1 [==============================] - 79s 79s/step
# 1/1 [==============================] - 7s 7s/step
